# %%
import json

# %%
import pandas as pd
df_mari = pd.read_csv("tweets_mari.csv")
df_kuma = pd.read_csv("tweets.csv")

# %%
kuma = set(df_kuma.text.str.extract("(@[a-zA-Z0-9_]*?) "))

# %%
mari = set(df_mari.text.str.extract("(@[a-zA-Z0-9_]*?) "))

# %%
df_kuma.text.map(lambda x : x[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-351-6609d28c8761> in <module>()
# ----> 1 df_kuma.text.map(lambda x : x[1])
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2043                                      index=self.index).__finalize__(self)
#    2044         else:
# -> 2045             mapped = map_f(values, arg)
#    2046             return self._constructor(mapped,
#    2047                                      index=self.index).__finalize__(self)
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:62187)()
#
# <ipython-input-351-6609d28c8761> in <lambda>(x)
# ----> 1 df_kuma.text.map(lambda x : x[1])
#
# IndexError: string index out of range

# %%
# %debug
# Out:
# > <ipython-input-351-6609d28c8761>(1)<lambda>()
# ----> 1 df_kuma.text.map(lambda x : x[1])
#
# ipdb> u
# > /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/series.py(2045)map()
#    2044         else:
# -> 2045             mapped = map_f(values, arg)
#    2046             return self._constructor(mapped,
#
# ipdb> x
# *** NameError: name 'x' is not defined
# ipdb> u
# > <ipython-input-351-6609d28c8761>(1)<module>()
# ----> 1 df_kuma.text.map(lambda x : x[1])
#
# ipdb> d
# > /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/series.py(2045)map()
#    2044         else:
# -> 2045             mapped = map_f(values, arg)
#    2046             return self._constructor(mapped,
#
# ipdb> d
# > <ipython-input-351-6609d28c8761>(1)<lambda>()
# ----> 1 df_kuma.text.map(lambda x : x[1])
#
# ipdb> x
# '#'
# ipdb> teet_id
# *** NameError: name 'teet_id' is not defined
# ipdb> u
# ...

# %%
data = df_kuma[df_kuma["text"].str.contains("(Ruby|Python)")][["timestamp","text"]]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel/__main__.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == '__main__':

# %%
data["lang"] = data.text.str.extract("(Ruby|Python)")

# %%
data["year"] = data["timestamp"][0:4]

# %%
data.value = 1

# %%
data.value
# Out:
# 1

# %%
kdalen(kuma)
# Out:
# 285

# %%
len(mari)
# Out:
# 38

# %%
kuma&maria
# Out:
# {nan,
#  '@YuiSaiki',
#  '@kkuma',
#  '@reiko18happy',
#  '@Kochisa127',
#  '@bowwow_24',
#  '@ochiai_yo',
#  '@Reiko18Happy',
#  '@hunnt431',
#  '@hisashikko',
#  '@ten0927',
#  '@abeyosuke',
#  '@Shintaro_iz',
#  '@chacokuma',
#  '@mari62',
#  '@kokifu85'}

# %%
df.datetime = pd.to_datetime(df["timestamp"])

# %%
df["month"] = pd.Series([line.strftime("%Y%m") for line in df.datetime])

# %%
df.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'month'],
#       dtype='object')

# %%
df[df["text"].str.startswith("@")][["tweet_id","timestamp","text"]]
# Out:
#                 tweet_id                  timestamp  \
# 5     475998482184937472  2014-06-09 13:50:56 +0000
# 19    420480903064715265  2014-01-07 09:03:54 +0000
# 25    396623199720308736  2013-11-02 13:01:54 +0000
# 29    383512727605358592  2013-09-27 08:45:34 +0000
# 33    368329405258399744  2013-08-16 11:12:28 +0000
# 35    366373619275796482  2013-08-11 01:40:52 +0000
# 36    366020983624183811  2013-08-10 02:19:37 +0000
# 50    346974971714752512  2013-06-18 12:57:34 +0000
# 53    343324669111308288  2013-06-08 11:12:34 +0000
# 56    338226935824015361  2013-05-25 09:36:00 +0000
# 57    338223374931210241  2013-05-25 09:21:51 +0000
# 64    325393895565443072  2013-04-19 23:42:04 +0000
# 65    325253866197229571  2013-04-19 14:25:39 +0000
# 72    319375449010618369  2013-04-03 09:06:55 +0000
# 74    319113751351685120  2013-04-02 15:47:01 +0000
# 76    319099866410266624  2013-04-02 14:51:51 +0000
# 77    319095775864971264  2013-04-02 14:35:36 +0000
# ...

# %%
mentions = df[df.text.str.contains("@")]

# %%
mention_to = mentions["text"].str.extract('(@[a-zA-Z0-9_]*?) ')

# %%
df.text.str.contains("(宝塚|ヅカ)").sum()/len(df)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel/__main__.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == '__main__':
# 0.02347762289068232

# %%
text = "".join(df.text)

# %%
res = mention_to.groupby(mention_to).size()

# %%
import collections
data = collections.Counter(mention_to).most_common(10)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df.groupby("month").size().plot()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 166

# %%
data = []
for tweet in tweets:
    if dateutil.parser.parse(tweet["timestamp"]).year == 2013:
        data.append(tweet["text"])

# %%
import re
data = []
for tweet in tweets:
    res = re.search("^(@.*?) ",tweet["text"])
    if res and dateutil.parser.parse(tweet["timestamp"]).year == 2015:
        data.append(res.group(1))

# %%
month = []
for tweet in tweets:
    month.append(tweet["timestamp"][0:7])

# %%
df[df.text.str.contains("彼[^女]")][["timestamp","text"]]
# Out:
#                       timestamp  \
# 97    2013-03-05 12:35:59 +0000
# 154   2012-10-14 13:39:42 +0000
# 174   2012-09-13 12:55:31 +0000
# 227   2012-07-07 14:08:53 +0000
# 316   2012-03-21 04:50:43 +0000
# 335   2012-03-01 15:03:22 +0000
# 410   2012-01-19 17:13:14 +0000
# 482   2011-12-06 03:50:50 +0000
# 579   2011-10-06 03:43:43 +0000
# 591   2011-09-22 17:00:46 +0000
# 620   2011-09-03 17:45:12 +0000
# 621   2011-09-03 17:36:59 +0000
# 622   2011-09-03 17:28:48 +0000
# 623   2011-09-03 17:17:55 +0000
# 624   2011-09-03 16:57:00 +0000
# 625   2011-09-03 16:45:34 +0000
# 627   2011-08-29 21:24:50 +0000
# 631   2011-08-26 15:05:26 +0000
# 682   2011-07-22 15:14:19 +0000
# 766   2011-05-29 13:14:53 +0000
# 774   2011-05-21 14:31:10 +0000
# 815   2011-04-20 22:59:36 +0000
# 829   2011-04-04 12:56:39 +0000
# 912   2011-01-01 01:46:13 +0000
# 925   2010-12-20 12:50:07 +0000
# 938   2010-12-05 14:03:23 +0000
# 943   2010-12-03 16:54:36 +0000
# 1008  2010-09-05 00:00:00 +0000
# ...

# %%
df["month"] = pd.Series([line[0:7] for line in df.timestamp])

# %%
df.groupby("month").size().plot()

# %%
word_ranking(text)
# Out:
# [('://', 48),
#  ('http', 47),
#  ('nakaoffy', 43),
#  ('kkuma', 43),
#  ('0930', 35),
#  ('pyuko', 35),
#  ('ricoryoko', 34),
#  ('ちゃん', 30),
#  ('bowwow', 29),
#  ('久しぶり', 29),
#  ('opalpanda', 28),
#  ('pocota', 28),
#  ('8806', 27),
#  ('shamu', 27),
#  ('orz', 24),
#  ('HIME', 22),
#  ('Happy', 21),
#  ('Reiko', 21),
#  ('びっくり', 20),
#  ('ところ', 19),
#  ('みんな', 18),
#  ('ロミジュリ', 18),
#  ('DVD', 18),
#  ('!!@', 17),
#  ('スーツ', 16),
#  ('com', 16),
#  ('eagle', 16),
#  ('テレビ', 16),
#  ('みたい', 15),
#  ('(｡-_-｡)', 15),
#  ('気持ち', 14),
#  ('ファン', 14),
#  (';_&', 14),
#  ('yfrog', 13),
#  ('大丈夫', 13),
#  ('Sayu', 12),
#  ('0608', 12),
#  ('～。@', 11),
#  ('0720', 11),
#  ('hoihoi', 11),
#  ('お世話', 11),
#  ('楽しみ', 10),
#  ('ロミオ', 10),
#  ('エリザ', 10),
#  ('1112', 10),
#  ('レベル', 10),
#  ('mtk', 10),
#  ('mari', 10),
#  ('トップ', 9),
#  ('ドラマ', 9),
#  ('御堂筋', 9),
#  ('wRT', 9),
#  ('お願い', 9),
#  ('!!」', 8),
#  ('こっち', 8),
#  ('結婚式', 8),
#  ('メール', 8),
#  ('サッカー', 8),
#  ('^^;', 8),
# ...

# %%
import MeCab
import collections
def word_ranking(text):
    mecab = MeCab.Tagger ("-Ochasen")
    mecab_result = mecab.parse(text)
    temp = [line.split("\t") for line in mecab_result.split("\n")]
    del temp[-2:]
    word = [line[0] for line in temp if "名詞" in line[3] and len(line[0]) >=3 ]
    data = collections.Counter(word)
    return [line for line in data.most_common() if line[1] >= 3]

# %%
word_ranking("".join(data))
# Out:
# [('://', 785),
#  ('http', 782),
#  ('booklog', 120),
#  ('まとめ', 35),
#  ('Ruby', 31),
#  ('データ', 28),
#  ('ニュース', 26),
#  ('little', 25),
#  ('hand', 25),
#  ('プログラミング', 23),
#  ('Web', 23),
#  ('Rails', 22),
#  ('ブログ', 20),
#  ('darimaru', 20),
#  ('サービス', 19),
#  ('ところ', 18),
#  ('miil', 17),
#  ('みたい', 17),
#  ('エンジニア', 16),
#  ('デザイン', 16),
#  ('tamami', 16),
#  ('1001', 16),
#  ('あなた', 16),
#  ('アプリ', 16),
#  ('NAVER', 16),
#  ('wakka', 15),
#  ('1986', 15),
#  ('...', 15),
#  ('Google', 14),
#  ('2013', 14),
#  ('kkuma', 14),
#  ('ネット', 14),
#  ('ビジネス', 13),
#  ('図書館', 12),
#  ('リーダー', 12),
#  ('SQL', 12),
#  ('テスト', 12),
#  ('使い方', 11),
#  ('ライブドアブログ', 11),
#  ('みんな', 11),
#  ('サイト', 11),
#  ('sho', 10),
#  ('Excel', 10),
#  ('...』', 10),
#  ('Tumblr', 10),
#  ('Text', 10),
#  ('^)／', 10),
#  ('ツール', 10),
#  ('ソフト', 10),
#  ('＼(^', 10),
#  ('Home', 10),
#  ('Nekopuni', 10),
#  ('100', 9),
#  ('スキル', 9),
#  ('iPhone', 9),
#  ('インストール', 9),
#  ('クック', 9),
#  ('WEB', 9),
# ...

# %%
ranking = []
for text in texts:
    ranking.append(word_ranking(text))

# %%
i = 1
for monthly_ranking in ranking:
    print("%i月:%s" % (i,monthly_ranking[0:5]))
    i = i + 1
